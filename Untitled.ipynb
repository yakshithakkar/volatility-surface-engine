# %%
import sys
print(sys.version)
# Out:
# 3.9.6 (default, Oct 17 2025, 17:15:53)
# [Clang 17.0.0 (clang-1700.4.4.1)]

# %%
# !pip install numpy scipy pandas yfinance plotly mibian requests streamlit
# Out:
# zsh:1: command not found: pip

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from scipy.optimize import brentq
import plotly.graph_objects as go

print("All imports OK 🚀")
# Out:
# All imports OK 🚀

# %%
import sys
# !{sys.executable} -m pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 9.9 MB 1.1 MB/s eta 0:00:01
# ...
#   WARNING: The script plotly_get_chrome is installed in '/Users/yakshithakker/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import mibian
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import mibian
#
# ModuleNotFoundError: No module named 'mibian'

# %%
pip install mibian
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Created wheel for mibian: filename=mibian-0.1.3-py3-none-any.whl size=4039 sha256=d134a2955b4e31b71252da8e9d7e4143261e6955590e7515dd29abbe75f25f77
#   Stored in directory: /Users/yakshithakker/Library/Caches/pip/wheels/43/b9/31/945abf284df5614e45ec4fccb8a892025987093558c94902fb
# Successfully built mibian
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

os.makedirs("vol_surface/data", exist_ok=True)

files = [
    "vol_surface/bs_model.py",
    "vol_surface/implied_vol.py",
    "vol_surface/surface.py",
    "vol_surface/main.py",
    "vol_surface/dashboard.py"
]

for f in files:
    open(f, "a").close()

print("Project structure ready")
# Out:
# Project structure ready

# %%
from vol_surface.bs_model import black_scholes_call, black_scholes_put

S, K, T, r, sigma = 100, 100, 1, 0.05, 0.2

print("Call:", black_scholes_call(S, K, T, r, sigma))
print("Put:", black_scholes_put(S, K, T, r, sigma))
# Out:
# Call: 10.450583572185565
# Put: 5.573526022256971

# %%
import os
print(os.getcwd())
# Out:
# /Users/yakshithakker/python/Volatility Surface project

# %%
# !python3 vol_surface/main.py
# Out:
# /Users/yakshithakker/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Spot Price: 740.5700073242188
#
# Available Expiries: ('2026-05-11', '2026-05-12', '2026-05-13', '2026-05-14', '2026-05-15')
# Using Expiry: 2026-05-11
# /Users/yakshithakker/python/Volatility Surface project/vol_surface/main.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calls["mid_price"] = (calls["bid"] + calls["ask"]) / 2
# /Users/yakshithakker/python/Volatility Surface project/vol_surface/main.py:50: SettingWithCopyWarning:
# ...

# %%
# !python3 vol_surface/main.py
# Out:
# /Users/yakshithakker/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Spot Price: 740.3599853515625
#
# Available Expiries: ('2026-05-11', '2026-05-12', '2026-05-13', '2026-05-14', '2026-05-15')
# Using Expiry: 2026-05-11
# Risk-Free Rate: 0.045
# Time to Expiry (Years): -0.0027397260273972603
# /Users/yakshithakker/python/Volatility Surface project/vol_surface/main.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calls["mid_price"] = (calls["bid"] + calls["ask"]) / 2
# ...

# %%
# !python3 vol_surface/main.py
# Out:
# /Users/yakshithakker/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Spot Price: 740.4639892578125
#
# Available Expiries: ('2026-05-11', '2026-05-12', '2026-05-13', '2026-05-14', '2026-05-15')
# Using Expiry: 2026-05-11
# Risk-Free Rate: 0.045
# Time to Expiry (Years): -0.0027397260273972603
# /Users/yakshithakker/python/Volatility Surface project/vol_surface/main.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calls["mid_price"] = (calls["bid"] + calls["ask"]) / 2
# ...

# %%
# !python3 vol_surface/main.py
# Out:
# /Users/yakshithakker/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Spot Price: 740.530029296875
#
# Available Expiries: ('2026-05-11', '2026-05-12', '2026-05-13', '2026-05-14', '2026-05-15')
# Using Expiry: 2026-05-11
# Risk-Free Rate: 0.045
# Time to Expiry (Years): -0.0027397260273972603
# /Users/yakshithakker/python/Volatility Surface project/vol_surface/main.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calls["mid_price"] = (calls["bid"] + calls["ask"]) / 2
# ...

# %%
# !python3 vol_surface/main.py
# Out:
# /Users/yakshithakker/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Spot Price: 740.5999755859375
#
# Available Expiries: ('2026-05-11', '2026-05-12', '2026-05-13', '2026-05-14', '2026-05-15')
# Using Expiry: 2026-05-11
# Risk-Free Rate: 0.045
# Time to Expiry (Years): -0.0027397260273972603
# /Users/yakshithakker/python/Volatility Surface project/vol_surface/main.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calls["mid_price"] = (calls["bid"] + calls["ask"]) / 2
# ...

# %%
# !python3 vol_surface/main.py
# Out:
# /Users/yakshithakker/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Spot Price: 740.3900146484375
#
# Available Expiries: ('2026-05-11', '2026-05-12', '2026-05-13', '2026-05-14', '2026-05-15')
# Using Expiry: 2026-05-18
# Risk-Free Rate: 0.045
# Time to Expiry (Years): 0.01643835616438356
# T: 0.01643835616438356
# /Users/yakshithakker/python/Volatility Surface project/vol_surface/main.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calls["mid_price"] = (calls["bid"] + calls["ask"]) / 2
# ...

# %%
# !python3 vol_surface/main.py
# Out:
# /Users/yakshithakker/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Spot Price: 740.3099975585938
#
# Available Expiries: ('2026-05-11', '2026-05-12', '2026-05-13', '2026-05-14', '2026-05-15')
# Using Expiry: 2026-05-18
# Risk-Free Rate: 0.045
# Time to Expiry (Years): 0.01643835616438356
# T: 0.01643835616438356
# /Users/yakshithakker/python/Volatility Surface project/vol_surface/main.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calls["mid_price"] = (calls["bid"] + calls["ask"]) / 2
# ...

# %%
# !python3 vol_surface/main.py
# Out:
# /Users/yakshithakker/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Spot Price: 740.3599853515625
#
# Available Expiries: ('2026-05-11', '2026-05-12', '2026-05-13', '2026-05-14', '2026-05-15')
# Using Expiry: 2027-01-15
# Risk-Free Rate: 0.045
# Time to Expiry (Years): 0.6794520547945205
# T: 0.6794520547945205
# /Users/yakshithakker/python/Volatility Surface project/vol_surface/main.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calls["mid_price"] = (calls["bid"] + calls["ask"]) / 2
# ...

# %%
# !python3 vol_surface/main.py
# Out:
# /Users/yakshithakker/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Spot Price: 740.2899780273438
#
# Available Expiries: ('2026-05-11', '2026-05-12', '2026-05-13', '2026-05-14', '2026-05-15')
# Using Expiry: 2027-01-15
# Risk-Free Rate: 0.045
# Time to Expiry (Years): 0.6794520547945205
# T: 0.6794520547945205
# /Users/yakshithakker/python/Volatility Surface project/vol_surface/main.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calls["mid_price"] = (calls["bid"] + calls["ask"]) / 2
# ...

# %%
# !python3 vol_surface/main.py
# Out:
# /Users/yakshithakker/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Spot Price: 740.0800170898438
#
# Available Expiries: ('2026-05-11', '2026-05-12', '2026-05-13', '2026-05-14', '2026-05-15')
# Using Expiry: 2027-01-15
# Risk-Free Rate: 0.045
# Time to Expiry (Years): 0.6767123287671233
# T: 0.6767123287671233
# /Users/yakshithakker/python/Volatility Surface project/vol_surface/main.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calls["mid_price"] = (calls["bid"] + calls["ask"]) / 2
# ...

# %%
# !python3 vol_surface/main.py
# Out:
# /Users/yakshithakker/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Spot Price: 739.7100219726562
# Processing expiry: 2026-05-11
# Traceback (most recent call last):
#   File "/Users/yakshithakker/python/Volatility Surface project/vol_surface/main.py", line 65, in <module>
#     expiry_date = datetime.strptime(
# NameError: name 'datetime' is not defined

# %%
# !python3 vol_surface/main.py
# Out:
# /Users/yakshithakker/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Spot Price: 739.75
# Processing expiry: 2026-05-11
# Processing expiry: 2026-05-12
# Processing expiry: 2026-05-13
# Processing expiry: 2026-05-14
# Processing expiry: 2026-05-15
# Processing expiry: 2026-05-18
# Processing expiry: 2026-05-19
# Processing expiry: 2026-05-20
#
# TOTAL OPTIONS: 528
#     strike  lastPrice    bid  ...  mid_price         T  expiry_label
# 9    670.0      68.19  70.26  ...     70.295 -0.005479    2026-05-11
# 10   671.0      68.97  69.27  ...     69.305 -0.005479    2026-05-11
# 11   672.0      68.33  68.27  ...     68.305 -0.005479    2026-05-11
# 12   675.0      62.27  65.27  ...     65.305 -0.005479    2026-05-11
# ...

# %%
# !python3 vol_surface/main.py
# Out:
# /Users/yakshithakker/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Spot Price: 739.47998046875
# Processing expiry: 2026-05-11
# Processing expiry: 2026-05-12
# Processing expiry: 2026-05-13
# Processing expiry: 2026-05-14
# Processing expiry: 2026-05-15
# Processing expiry: 2026-05-18
# Processing expiry: 2026-05-19
# Processing expiry: 2026-05-20
#
# TOTAL OPTIONS: 529
#     strike  lastPrice    bid  ...  mid_price         T  expiry_label
# 9    670.0      68.19  70.46  ...     70.505 -0.005479    2026-05-11
# 10   671.0      68.97  69.46  ...     69.505 -0.005479    2026-05-11
# 11   672.0      68.33  68.29  ...     68.335 -0.005479    2026-05-11
# 12   675.0      62.27  65.40  ...     65.445 -0.005479    2026-05-11
# ...

# %%
# !python3 vol_surface/main.py
# Out:
# /Users/yakshithakker/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Spot Price: 739.3150024414062
# Processing expiry: 2026-05-11
# Processing expiry: 2026-05-12
# Processing expiry: 2026-05-13
# Processing expiry: 2026-05-14
# Processing expiry: 2026-05-15
# Processing expiry: 2026-05-18
# Processing expiry: 2026-05-19
# Processing expiry: 2026-05-20
#
# TOTAL OPTIONS: 529
#     strike  lastPrice    bid  ...  mid_price         T  expiry_label
# 9    670.0      68.19  70.25  ...     70.285 -0.005479    2026-05-11
# 10   671.0      68.97  69.25  ...     69.290 -0.005479    2026-05-11
# 11   672.0      68.33  68.25  ...     68.285 -0.005479    2026-05-11
# 12   675.0      62.27  65.25  ...     65.285 -0.005479    2026-05-11
# ...
